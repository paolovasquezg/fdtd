# %% [markdown]
# ## FDTD: 2D
#
# We have TM<sup>z</sup> and TE<sup>z</sup> polarization
#
# - TM<sup>z</sup>: E<sub>z</sub>, H<sub>x</sub> and H<sub>y</sub>
# - TE<sup>z</sup>: H<sub>z</sub>, E<sub>x</sub> and z<sub>y</sub>
#
# Revise ```tmz``` and ```tez``` for clarification

# %% [markdown]
# ### I. TM<sup>z</sup> polarization
#
# Assuming change in x,y tangential to z: Tangential Magnetic respect to z

# %% [markdown]
# #### a. Grid alignment
#
# ![tmz-grid](imgs/tmz-grid.png)

# %% [markdown]
# #### b. TFSF
#
# ![tmz-tfsf](imgs/tmz-tfsf.png)

# %% [markdown]
# #### c. PEC
#
# ![tmz-pec](imgs/tmz-pec.png)

# %% [markdown]
# ### II. TE<sup>z</sup> polarization
#
# Assuming change in x,y tangential to z: Tangential Electric respect to z

# %% [markdown]
# #### a. Grid alignment
#
# ![tez-grid](imgs/tez-grid.png)

# %% [markdown]
# #### b. TFSF
#
# ![tez-tfsf](imgs/tez-tfsf.png)

# %% [markdown]
# #### c. PEC
#
# ![tez-pec](imgs/tez-pec.png)
