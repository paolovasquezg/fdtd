# %% [markdown]
# ## FDTD: 3D
#
# We have the following update equations:
#
# ##### a. Electric field:
# - E<sub>x</sub>, E<sub>y</sub>, E<sub>z</sub>
#
# ##### b. Magnetic field:
# - H<sub>x</sub>, H<sub>y</sub>, H<sub>z</sub>

# %% [markdown]
# ### I. Yee Cell and Cube

# %% [markdown]
# ![yee-cc](imgs/cc.png)

# %% [markdown]
# ### II. Equations

# %% [markdown]
# ![eqs](imgs/eqs.png)

# %% [markdown]
# ### III. Coefficents

# %% [markdown]
# ![coef](imgs/coef.png)

# %% [markdown]
# ### IV. Grid Disposition

# %% [markdown]
# ![grid](imgs/grid.png)

# %% [markdown]
# ### V. TFSF

# %% [markdown]
# #### a. Constant x

# %% [markdown]
# ![constx](imgs/const-x.png)

# %% [markdown]
# #### b. Constant y

# %% [markdown]
# ![consty](imgs/consty.png)

# %% [markdown]
# #### c. Constant z

# %% [markdown]
# ![constz](imgs/constz.png)

# %% [markdown]
# ### VI. Non Simetric Grid

# %% [markdown]
# ![igls](imgs/igls.png)

# %% [markdown]
# #### a. Equations

# %% [markdown]
# ![eqs2](imgs/eqs2.png)

# %% [markdown]
# #### b. Coefficients

# %% [markdown]
# ![coef2](imgs/coef2.png)

# %% [markdown]
# ### VII. Wave Max Movement

# %% [markdown]
# ![wmove](imgs/wmove.png)
